# %%
#importing packages
import requests
import re
from bs4 import BeautifulSoup

#Webscraping for NYC slang
URL = "https://www.berlitz.com/blog/new-york-nyc-slang"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

results = soup.find(id="___gatsby")

print(results.prettify())
# Out:
# <div id="___gatsby">
#  <div id="gatsby-focus-wrapper" style="outline:none" tabindex="-1">
#   <div class="styles__PageWrapper-sc-1d079w9-0 eydJxD">
#    <div class="styles__PageInner-sc-1d079w9-2 hUutyf">
#     <div class="Spacerstyle__SpacerWithChildren-sc-18g3vvg-1 ehEHOo">
#      <div aria-hidden="false" class="TopNavstyle__Wrapper-sc-1h2bs0c-5 eaQBQE" data-key="max-header">
#       <nav aria-label="Secondary Navigation" class="TopNavstyle__Container-sc-1h2bs0c-6 zMiKv" data-key="max-header__top-bar">
#        <ul aria-label="Secondary Navigation Menu" class="TopNavstyle__Column-sc-1h2bs0c-8 fmPhBE" data-key="max-header__top-bar__left">
#         <li class="TopNavstyle__NavListItem-sc-1h2bs0c-0 ckDNXu" data-key="max-header__left-column__link-0">
#          <a data-key="top-nav__link" href="/language-centers" style="display:flex">
#           <span>
#            🇺🇸
#           </span>
#          </a>
#         </li>
# ...

# %%
#Parsing html code for NYC slang,then appending the words to a list
slang_words = results.find_all("tr") 
slang_list = []
for slang in slang_words:
    definitions = slang.find_all("td", limit=1)
    for word in definitions:
        slang_list.append((word.text.lower()).replace("’",""))

# %%
print(slang_list)
# Out:
# ['new york slang', 'the city', 'mad', 'pie', 'yerrr/yurrr', 'wack', 'bet', 'dead ass', 'dead', 'bop', 'brolic', 'cop', 'yeah nah', 'nah yeah', 'good looks', 'gucci', 'schlep', 'kid/son', 'grill', 'baconeggandcheese', 'brick', 'real talk', 'ratchet', 'frontin', 'cringe', 'woke', 'lit', 'shook', 'schmear', 'popo', 'sus', 'whip', 'tight', 'no cap', 'yas/yaaas', 'buggin', 'heard', 'wildin/wylin', 'crusty', 'book it', 'aggy', 'bev', 'link', 'peep', 'beef', 'shorty/shawty', 'thirsty', 'finna', 'bodega', 'ock', 'trippin', 'cake', 'a minute', 'get a slice', 'johnny pump', 'straphanger', 'downtown', 'slaps', 'take the l', 'snack', 'periodt', 'bomb', 'regular coffee', 'high key', 'low key', 'beastin', 'b', 'scrap', 'jack', 'flip', 'grimy', 'gotchu', 'on deck', 'no doubt', 'an l', 'word (up)', 'cheddar/cheese/paper/green', 'schvitz', 'drid', 'smacked', 'bird', 'mack', 'bag', 'we out', 'bronx slang', 'bronx cheer', 'od/odee', 'dumb', 'bread', 'creatures', 'bro', 'bruh', 'draggin it', 'hollywood'
# ...

# %%
#Webscraping for British slang
URL = "https://www.wix.com/wordsmatter/blog/2020/10/british-slang-words/"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

results1 = soup.find(id="SITE_CONTAINER")
print(results1.prettify())
# Out:
# <div id="SITE_CONTAINER">
#  <div class="main_MF" id="main_MF">
#   <div aria-label="top of page" class="Vd6aQZ ignore-focus SCROLL_TO_TOP" id="SCROLL_TO_TOP" role="region" tabindex="-1">
#    <span class="mHZSwn">
#     top of page
#    </span>
#   </div>
#   <div class="BACKGROUND_GROUP" id="BACKGROUND_GROUP">
#    <div id="BACKGROUND_GROUP_TRANSITION_GROUP">
#     <div class="pageBackground_e4p79 BmZ5pC" data-media-height-override-type="" data-media-position-override="false" id="pageBackground_e4p79">
#      <div class="MW5IWV" data-hook="bgLayers" id="bgLayers_pageBackground_e4p79">
#       <div class="LWbAav Kv1aVt" data-testid="colorUnderlay">
#       </div>
#       <div class="VgO9Yg" id="bgMedia_pageBackground_e4p79">
#       </div>
#       <div class="m4khSP" data-testid="bgOverlay">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="site-root" id="site-root">
#    <div class="mesh-layout masterPage" id="masterPage">
# ...

# %%
#Parsing html code for British slang,then appending the words to a list
british_words = results1.find_all('h2')
british_list = []
for slang in british_words:
  definitions = slang.find_all("span", limit = 1)
  for word in definitions:
    new_string = ''
    for characters in word:
      if characters == '’':
        new_chr = "'"
      else:
        new_chr = characters
      new_string += new_chr.text
    british_list.append((new_string[4:]).lower())

british_list
# Out:
# ['arse',
#  'banter',
#  'bare',
#  'barmy',
#  'bender',
#  'bloke',
#  'bollocking',
#  'bollocks',
#  'bonkers',
#  'bonnie',
#  'bruv',
#  'bugger all',
#  'buzzin’',
#  'cheers',
#  'chippy',
#  'chuffed',
#  'cor blimey',
#  'course',
#  'creps',
#  'dead',
#  'dodgy',
#  'dosh',
#  'ends',
#  'fag',
#  'fancy',
#  'fam',
#  'fiver',
#  'food',
#  'footie',
#  'gaff',
#  'gaffer',
#  'gagging',
#  'galdem',
#  'geordie',
#  'gob',
#  'gordon bennett!',
#  'grand',
#  'grass up',
#  'have a strop',
#  'innit',
#  'jiffy',
#  'jokes',
#  'knackered',
#  'knees-up',
#  'knob',
#  'long',
#  'loo',
#  'lush',
#  'manc',
#  'mandem',
#  'manor',
#  'mate ',
#  'mental',
#  'merc (or merk or murk)',
#  'mint',
#  'minted',
#  'moolah',
#  'mug',
#  'naff',
#  'nick',
#  'nicked',
#  'nippy',
#  'nutter',
#  'pagan',
#  'peng',
#  'pig’s ear',
#  'pillock',
#  'pint',
#  'plonker',
#  'porkies',
#  'p’s',
#  'pub',
#  'punter',
#  'quid',
#  'rugger',
#  'scouser',
#  'shag',
# ...

# %%
british_list

# %%
#Webscraping for california slang
URL = "https://www.berlitz.com/blog/california-slang-words"
page = requests.get(URL)
soup = BeautifulSoup(page.content, "html.parser")

results = soup.find(id="___gatsby")
print(results.prettify())
# Out:
# <div id="___gatsby">
#  <div id="gatsby-focus-wrapper" style="outline:none" tabindex="-1">
#   <div class="styles__PageWrapper-sc-1d079w9-0 eydJxD">
#    <div class="styles__PageInner-sc-1d079w9-2 hUutyf">
#     <div class="Spacerstyle__SpacerWithChildren-sc-18g3vvg-1 ehEHOo">
#      <div aria-hidden="false" class="TopNavstyle__Wrapper-sc-1h2bs0c-5 eaQBQE" data-key="max-header">
#       <nav aria-label="Secondary Navigation" class="TopNavstyle__Container-sc-1h2bs0c-6 zMiKv" data-key="max-header__top-bar">
#        <ul aria-label="Secondary Navigation Menu" class="TopNavstyle__Column-sc-1h2bs0c-8 fmPhBE" data-key="max-header__top-bar__left">
#         <li class="TopNavstyle__NavListItem-sc-1h2bs0c-0 ckDNXu" data-key="max-header__left-column__link-0">
#          <a data-key="top-nav__link" href="/language-centers" style="display:flex">
#           <span>
#            🇺🇸
#           </span>
#          </a>
#         </li>
# ...

# %%
#Parsing html code for California slang,then appending the words to a list
cali_words = results.find_all("tr") 
cali_list = []
for slang in cali_words:
    definitions = slang.find_all("td", limit=1)
    for word in definitions:
        print(word.text)
        cali_list.append((word.text).lower())
# Out:
# Cali slang
# NorCal
# SoCal
# Come up
# Cruise
# Mob
# Dude
# Butthurt
# Drag
# Swoop
# Post up
# Dank
# Bail
# Bum
# Rock
# Los Angeles slang
# You know
# Yeah no
# No yeah
# WeHo
# NoHo
# “The” before “freeway”
# SigAlert
# May gray / June gloom
# Legit
# Grip
# For sure
# For real
# Like
# Down
# The industry
# Orange County slang
# Stoked
# Sick
# Rad
# Grom
# Gnarly
# Dude
# Dope
# Bro, brah, bruh
# Bomb
# Amped
# Heavy
# San Francisco slang
# Yadadamean
# Tryna
# The Town
# The City
# Slaps
# Put on blast
# No “the” before “freeway”
# Outta pocket
# Hyphy
# Hella
# Hecka
# Good looks
# Finna
# Dip
# San Diego slang
# Scoop or scoop
# Clutch
# Zonie
# Kook
# Hodad
# Chulajuana
# TJ
# Santa Anas
# Pero like
# Daygo
# PB
# OB
# Sacramento slang
# Up the hill
# The Delta
# The Sierra
# Placer
# Old Sac
# The claw
# The W-X
# Silicon Valley slang
# Zombie mode
# Unicorn
# Three commas club
# Tech bro
# Stealth mode
# Phubbing
# Joog
# Dogfooding
# Brogrammer
# Beta
# ...

# %%
#creating a function that identifies region based on amount of regional slang words used based on the webscraped lists
         
def parse(sentence):
  i = 0
  j = 0
  k = 0
  for word in cali_list:
    if re.findall(r'\W' + '(' + word + ')' + '\W', " " +  sentence + " ", re.IGNORECASE):
      i += len(re.findall(r'\W' + '(' + word + ')' + '\W', " " + sentence + " ", re.IGNORECASE))
  for word in slang_list:
    if re.findall(r'\W' + '(' + word + ')' + '\W', " " + sentence + " ", re.IGNORECASE):
      j += len(re.findall(r'\W' + '(' + word + ')' + '\W', " " +  sentence + " ", re.IGNORECASE))
  for word in british_list:
    if re.findall(r'\W' + '(' + word + ')' + '\W', " " + sentence + " ", re.IGNORECASE):
      k += len(re.findall(r'\W' + '(' + word + ')' + '\W', " " + sentence + " ", re.IGNORECASE))
  counter_list = [i,j,k]
  if max(counter_list) == i:
    print("California")
  elif max(counter_list) == j:
    print("New York")
  elif max(counter_list) == k:
    print("Britain")
  else:
    print("No Slang Detected")
  #elif(j == i == k and i != 0 and j != 0 and k != 0):
      #print("Widespread")

# %%
#testing strings
test_str = "Come up here."
parse(test_str)
test_str1 = "Bruv bloke"
parse(test_str1)
# Out:
# California
# Britain

# %%
for word in slang_list:
    if word in cali_list and word in slang_list:
        print(word)
# Out:
# the city
# good looks
# finna
# slaps
# bomb
# sick
# text slang abbreviation
# lmao
# def
# wya
# nbd

# %%
#create a master list of slang
# Out:
# p

# %%
print(cali_list + slang_list)
# Out:
# ['cali slang', 'norcal', 'socal', 'come up', 'cruise', 'mob', 'dude', 'butthurt', 'drag', 'swoop', 'post up', 'dank', 'bail', 'bum', 'rock', 'los angeles slang', 'you know', 'yeah no', 'no yeah', 'weho', 'noho', '“the” before “freeway”', 'sigalert', 'may gray / june gloom', 'legit', 'grip', 'for sure', 'for real', 'like', 'down', 'the industry', 'orange county slang', 'stoked', 'sick', 'rad', 'grom', 'gnarly', 'dude', 'dope', 'bro, brah, bruh', 'bomb', 'amped', 'heavy', 'san francisco slang', 'yadadamean', 'tryna', 'the town', 'the city', 'slaps', 'put on blast', 'no “the” before “freeway”', 'outta pocket', 'hyphy', 'hella', 'hecka', 'good looks', 'finna', 'dip', 'san diego slang', 'scoop or scoop', 'clutch', 'zonie', 'kook', 'hodad', 'chulajuana', 'tj', 'santa anas', 'pero like', 'daygo', 'pb', 'ob', 'sacramento slang', 'up the hill', 'the delta', 'the sierra', 'placer', 'old sac', 'the claw', 'the w-x', 'silicon valley slang', 'zombie mode', 'unicorn', 'three commas club', 'tech br
# ...
